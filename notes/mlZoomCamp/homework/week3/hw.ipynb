# %%
import pandas as pd


df = pd.read_csv('course_lead_scoring.csv')
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %%
df['industry'].mode()
# Out:
# 0    retail
# Name: industry, dtype: object

# %%
df.dtypes
numerical = ['number_of_courses_viewed', 'annual_income', 'interaction_count', 'lead_score', 'converted']
categorical = []
for col in df.columns:
    if col not in numerical:
        categorical.append(col)

df[numerical].corr()
# Out:
#                           number_of_courses_viewed  annual_income  \
# number_of_courses_viewed                  1.000000       0.031551
# annual_income                             0.031551       1.000000
# interaction_count                        -0.023565       0.048618
# lead_score                               -0.004879       0.005334
# converted                                 0.435914       0.078256
#
#                           interaction_count  lead_score  converted
# number_of_courses_viewed          -0.023565   -0.004879   0.435914
# annual_income                      0.048618    0.005334   0.078256
# interaction_count                  1.000000    0.009888   0.374573
# lead_score                         0.009888    1.000000   0.193673
# converted                          0.374573    0.193673   1.000000

# %%
from sklearn.model_selection import train_test_split


target = df.converted

# split
df_full_train, df_test = train_test_split(df, test_size= 0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size= 0.25, random_state=42)

# get target
y_train = df_train.converted.values
y_val = df_val.converted.values
y_test = df_test.converted.values

# Remove target column from features
df_train = df_train.drop(columns=['converted'])
df_val = df_val.drop(columns=['converted'])
df_test = df_test.drop(columns=['converted'])

# %%
from sklearn.metrics import mutual_info_score


mutual_info_score(df_train.industry.fillna('null'), y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 from sklearn.metrics import mutual_info_score
# ----> 2 mutual_info_score(df_train.industry, y_train)
#
# File c:\Users\danie\files\repos\leaning-in-public\notes\mlZoomCamp\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\danie\files\repos\leaning-in-public\notes\mlZoomCamp\.venv\Lib\site-packages\sklearn\metrics\cluster\_supervised.py:886, in mutual_info_score(labels_true, labels_pred, contingency)
#     820 """Mutual Information between two clusterings.
#     821
#     822 The Mutual Information is a measure of the similarity between two labels
#    (...)    883 0.0566
#     884 """
#     885 if contingency is None:
# --> 886     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#     887     contingency = contingency_matrix(labels_true, labels_pred, sparse=True)
#     888 else:
#
# File c:\Users\danie\files\repos\leaning-in-public\notes\mlZoomCamp\.venv\Lib\site-packages\sklearn\metrics\cluster\_supervised.py:35, in check_clusterings(labels_true, labels_pred)
#      24 def check_clusterings(labels_true, labels_pred):
#      25     """Check that the labels arrays are 1D and of same dimension.
#      26
#      27     Parameters
#    (...)     33         The predicted labels.
#      34     """
# ---> 35     labels_true = check_array(
#      36         labels_true,
#      37         ensure_2d=False,
#      38         ensure_min_samples=0,
#      39         dtype=None,
#      40     )
#      42     labels_pred = check_array(
#      43         labels_pred,
#      44         ensure_2d=False,
#      45         ensure_min_samples=0,
#      46         dtype=None,
#      47     )
#      49     type_label = type_of_target(labels_true)
#
# File c:\Users\danie\files\repos\leaning-in-public\notes\mlZoomCamp\.venv\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\danie\files\repos\leaning-in-public\notes\mlZoomCamp\.venv\Lib\site-packages\sklearn\utils\validation.py:105, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     103 if not is_array_api and X.dtype == np.dtype("object") and not allow_nan:
#     104     if _object_dtype_isnan(X).any():
# --> 105         raise ValueError("Input contains NaN")
#     107 # We need only consider float arrays, hence can early return for all else.
#     108 if not xp.isdtype(X.dtype, ("real floating", "complex floating")):
#
# ValueError: Input contains NaN
